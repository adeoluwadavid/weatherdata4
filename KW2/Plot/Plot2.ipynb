# %%
import File
import widget as wd
from Plot2 import weatherData

# %%
display(wd.widgetSelection, wd.start, wd.end, wd.widgetDataToPlot)
# Out:
# Dropdown(description='Selection:', options=('Mean', 'Median', 'Standard_Deviation', 'Frequency'), value='Mean'…
# DatePicker(value=datetime.date(2019, 1, 1), description='Start Date: ')
# DatePicker(value=datetime.date(2019, 11, 28), description='End Date: ')
# Dropdown(description='Data To Plot:', options=('Temperature', 'Dew_Point', 'Humidity', 'Wind_Speed', 'Wind_Gus…

# %%
weatherData(wd.widgetSelection.value,wd.start.value,wd.end.value,wd.widgetDataToPlot.value)
