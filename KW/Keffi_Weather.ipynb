# %%
import import_file

# %%
display(wd.start_date,wd.end_date, wd.widgetDataToPlot)

# %%
weatherData(wd.start_date.value,wd.end_date.value,wd.widgetDataToPlot.value)
# Out:
# Mean:  27.758169934640517
# Median:  27.222222222222225
# STD:  3.155895060010789
# Max value 33.88888888888889
# Min value 22.22222222222222
